# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
with open('./log_jovian.txt') as f:
    data = f.readlines()

# %%
jovian_time = np.array([int(_.strip().split(',')[0].strip('()')) for _ in data[::2]])

# %%
jovian_time.shape
# Out:
# (799999,)

# %%
jovian_time = np.diff(jovian_time)

# %%
local_time = np.array([float(_.strip()) for _ in data[1::2]])

# %%
local_time.shape
# Out:
# (799999,)

# %%
plot(jovian_time, '.')

# %%
plot(local_time,'.')

# %%
hist(local_time,bins=15);

# %%
hist(jovian_time,bins=15);

# %%
mean(local_time), std(local_time)
# Out:
# (17.751937806017573, 3.4192166087434988)

# %%
mean(jovian_time), std(jovian_time)
# Out:
# (17.77859819649549, 3.524289100724571)
